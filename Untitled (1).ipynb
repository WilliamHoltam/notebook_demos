# %% [markdown]
# # Investigate UK Policing Open Data

# %% [markdown]
# Install 3rd party libraries

# %%
# !pip install pathlib
# Out:
# Collecting pathlib
#   Downloading pathlib-1.0.1.tar.gz (49 kB)
#      |████████████████████████████████| 49 kB 2.9 MB/s eta 0:00:011
# Building wheels for collected packages: pathlib
#   Building wheel for pathlib (setup.py) ... done
#   Created wheel for pathlib: filename=pathlib-1.0.1-py3-none-any.whl size=14346 sha256=7fe69acff80252caecae5d170f77458d626a399969de41ce2499b472072f85e6
#   Stored in directory: /home/jovyan/.cache/pip/wheels/6e/96/b8/10037fe231e23970bac58361d7c93571ab983a7bbc55e68550
# Successfully built pathlib
# Installing collected packages: pathlib
# Successfully installed pathlib-1.0.1

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# First we define a function to read the data into memory.
#
# This function uses pattern matching to itterate through all CSV's in a directory. It then builds a Python dictionary {key: value}.
# * Each key is the filename of the data which has been imported
# * Each value is the dataset itself stored as a Pandas DataFrame.

# %%
# def read_csv(file_path, dictionary):
#     try:
#         print("Loading", file.as_posix())
#         data = pd.read_csv(file_path.as_posix(), encoding='utf-8')
#         dictionary[file.name] = data
#     except:
#         print('Unable to load', file.as_posix())
#     return dictionary

# %%
def read_csvs_from_path(path):
    """Read csv's from a directory 
    """
    data_dict = {}
    for file in path.glob("*.csv"):
        print("Loading", file.as_posix())
        try:
            data = pd.read_csv(file.as_posix(), encoding='utf-8')
            data_dict[file.name] = data
        except:
            print('Unable to load', file.as_posix())
    return data_dict

# %% [markdown]
# Call the function defined above and read the data into memory.

# %%
data_path = Path.cwd()/"data/police/"
data_dictionary = read_csvs_from_path(path=data_path)
# Out:
# Loading /home/jovyan/demo/data/police/victim-satisfaction-september-2014.csv
# Loading /home/jovyan/demo/data/police/victim-satisfaction-supplementary-data-september-2011-12-13-14.csv
# Loading /home/jovyan/demo/data/police/domestic-abuse-force-data.csv
# Loading /home/jovyan/demo/data/police/Principal_Offence_Category_Jul.csv
# Loading /home/jovyan/demo/data/police/crime-data-2014.csv
# Loading /home/jovyan/demo/data/police/police-corruption-and-integrity-data-2014.csv
# Loading /home/jovyan/demo/data/police/anti-social-behaviour-ipsos-mori-survey-results-by-force-20101107.csv
# Unable to load /home/jovyan/demo/data/police/anti-social-behaviour-ipsos-mori-survey-results-by-force-20101107.csv

# %% [markdown]
# Examine one of the datasets

# %% [markdown]
# ## Victim Satisfaction September 2014

# %% [markdown]
# Sense check the first 5 lines of the dataset.

# %%
vs = data_dictionary["victim-satisfaction-september-2014.csv"]

# %%
vs.head()
# Out:
#           Unnamed: 0  \
# 1  England and Wales
# 2  Avon and Somerset
# 3       Bedfordshire
# 4     Cambridgeshire
# 5           Cheshire
#
#   Percentage of respondents satisfied with overall service in 12 months to September 2014  \
# 1                                        84.65958887
# 2                                        86.90199853
# 3                                        82.98896335
# 4                                         88.0226079
# 5                                        85.71085836
#
#   Confidence Interval percentage of respondents satisfied with overall service in 12 months to September 2014  \
# 1                                        0.193316511
# 2                                        1.204243724
# 3                                        0.141522058
# 4                                        1.292982385
# 5                                        2.270781116
#
#   Percentage of respondents satisfied with overall service in 12 months to September 2013  \
# 1                                        85.19290111
# 2                                        88.47406666
# 3                                        82.72559013
# 4                                         88.3886854
# 5                                        88.44768422
#
#   Confidence Interval percentage of respondents satisfied with overall service in 12 months to September 2013  \
# 1                                        0.193038116
# 2                                        1.126108106
# 3                                        0.151133387
# 4                                        1.245046877
# 5                                        1.683268205
#
#   Percentage of respondents satisfied with overall service in 12 months to September 2012  \
# 1                                         84.0170667
# 2                                        86.02625194
# 3                                        80.62057391
# 4                                        85.08982667
# 5                                        85.97406648
#
#   Confidence Interval percentage of respondents satisfied with overall service in 12 months to September 2012  \
# 1                                        0.199411201
# 2                                        1.151571599
# 3                                        1.432649175
# 4                                        1.466929249
# 5                                        1.902107024
#
#   Percentage of respondents satisfied with overall service in 12 months to September 2011  \
# 1                                        83.90741135
# 2                                        88.18922215
# 3                                        79.98706296
# 4                                        86.20820289
# 5                                        86.95894511
#
#   Confidence Interval percentage of respondents satisfied with overall service in 12 months to September 2011
# 1                                        0.192521391
# 2                                        1.001747595
# 3                                        1.495882465
# 4                                        1.368555175
# 5                                        1.683892041

# %%
vs.dtypes

# %%
float_columns = vs.columns[1:]
object_columns = vs.columns[0]

# %%
vs.dtypes
# Out:
# Unnamed: 0                                                                                                     object
# Percentage of respondents satisfied with overall service in 12 months to September 2014                        object
# Confidence Interval percentage of respondents satisfied with overall service in 12 months to September 2014    object
# Percentage of respondents satisfied with overall service in 12 months to September 2013                        object
# Confidence Interval percentage of respondents satisfied with overall service in 12 months to September 2013    object
# Percentage of respondents satisfied with overall service in 12 months to September 2012                        object
# Confidence Interval percentage of respondents satisfied with overall service in 12 months to September 2012    object
# Percentage of respondents satisfied with overall service in 12 months to September 2011                        object
# Confidence Interval percentage of respondents satisfied with overall service in 12 months to September 2011    object
# dtype: object

# %%
for column in float_columns:
    vs[column] = vs[column].astype('float32')

# %%
vs = data_dictionary["victim-satisfaction-september-2014.csv"]
sns.barplot(x='Unnamed: 0', y='Percentage of respondents satisfied with overall service in 12 months to September 2014', data=vs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-118-16b645ec378c> in <module>
#       1 vs = data_dictionary["victim-satisfaction-september-2014.csv"]
# ----> 2 sns.barplot(x='Unnamed: 0', y='Percentage of respondents satisfied with overall service in 12 months to September 2014', data=vs)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1607                                  order, hue_order, units)
#    1608         self.establish_colors(color, palette, saturation)
# -> 1609         self.estimate_statistic(estimator, ci, n_boot)
#    1610
#    1611         self.dodge = dodge
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/seaborn/categorical.py in estimate_statistic(self, estimator, ci, n_boot)
#    1491                     statistic.append(np.nan)
#    1492                 else:
# -> 1493                     statistic.append(estimator(stat_data))
#    1494
#    1495                 # Get a confidence interval for this estimate
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    3371
#    3372     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 3373                           out=out, **kwargs)
#    3374
#    3375
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#     170             ret = ret.dtype.type(ret / rcount)
#     171     else:
# --> 172         ret = ret / rcount
#     173
#     174     return ret
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
for key in data_dictionary.keys():
    data_dictionary[key] = data_dictionary[key].dropna()

# %% [markdown]
# # Victim Satisfaction

# %%
print(list(data_dictionary.keys())[0])
victim satisfaction = data_dictionary[list(data_dictionary.keys())[0]].head()
# Out:
#   File "<ipython-input-104-d5d4b35e3724>", line 2
#     victim satisfaction = data_dictionary[list(data_dictionary.keys())[0]].head()
#                       ^
# SyntaxError: invalid syntax

# %%
sns.plot(dat_dictionary)
